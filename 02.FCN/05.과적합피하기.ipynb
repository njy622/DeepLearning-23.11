# %% [markdown]
# ## 과적합 피하기 - 초음파 광물 데이터

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
seed =2023
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/sonar.csv', header=None)
df.head(3)
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
#
# [3 rows x 61 columns]

# %%
df[60].value_counts()
# Out:
# M    111
# R     97
# Name: 60, dtype: int64

# %%
# X data: scaling
from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(df.iloc[:, :-1].values)  # 행은 전부 열은 -1까지

# %%
# y data: label encoding
from sklearn.preprocessing import LabelEncoder
y_labeled = LabelEncoder().fit_transform(df[60].values)

# %%
# dataset 분리
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_labeled, stratify=y_labeled, test_size=0.2, random_state=seed
)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# - Case 1) 은닉층 2개

# %%
model1 = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                4880
#
#  dense_1 (Dense)             (None, 12)                972
#
#  dense_2 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 5865 (22.91 KB)
# Trainable params: 5865 (22.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model1.compile('adam', 'binary_crossentropy', metrics=['accuracy'])
hist1 = model1.fit(X_train, y_train, validation_split=0.2,
                   epochs=200, batch_size=100, verbose=0)
model1.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3909 - accuracy: 0.8810
# [0.3909381628036499, 0.8809523582458496]

# %%
hl1, params1, acc1 = 2, 5865, 0.8095        # 은닉층 2개, 파람수갯수는 5865, 정확도는 0.8095

# %% [markdown]
# - Case 2) 은닉층 4개

# %%
model2 = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(48, activation='relu'),
    Dense(20, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
])
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 80)                4880
#
#  dense_4 (Dense)             (None, 48)                3888
#
#  dense_5 (Dense)             (None, 20)                980
#
#  dense_6 (Dense)             (None, 8)                 168
#
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 9925 (38.77 KB)
# Trainable params: 9925 (38.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model2.compile('adam', 'binary_crossentropy', metrics=['accuracy'])
hist2 = model2.fit(X_train, y_train, validation_split=0.2,
                   epochs=200, batch_size=100, verbose=0)
model2.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6259 - accuracy: 0.8571
# [0.6259453296661377, 0.8571428656578064]

# %%
hl2, params2, acc2 = 4, 9925, 0.8333         # 은닉층 4개, 파람수갯수는 9925, 정확도는 0.8095(앞에 내용은 선생님 데이터)

# %% [markdown]
# - Case 3) 은닉층 6개

# %%
model3 = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(64, activation='relu'),
    Dense(40, activation='relu'),
    Dense(24, activation='relu'),
    Dense(10, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 80)                4880
#
#  dense_9 (Dense)             (None, 64)                5184
#
#  dense_10 (Dense)            (None, 40)                2600
#
#  dense_11 (Dense)            (None, 24)                984
#
#  dense_12 (Dense)            (None, 10)                250
#
#  dense_13 (Dense)            (None, 4)                 44
#
#  dense_14 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 13947 (54.48 KB)
# Trainable params: 13947 (54.48 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model3.compile('adam', 'binary_crossentropy', metrics=['accuracy'])
hist3 = model3.fit(X_train, y_train, validation_split=0.2,
                   epochs=200, batch_size=100, verbose=0)
model3.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9182 - accuracy: 0.8810
# [0.9182083606719971, 0.8809523582458496]

# %%
hl3, params3, acc3 = 6, 13947, 0.8333            # 은닉층 6개, 파람수갯수는 13947, 정확도는 0.8333

# %% [markdown]
# - Case 4) 은닉층 8개

# %%
model4 = Sequential([
    Dense(80, input_dim=60, activation='relu'),          # 여기부터 은닉층
    Dense(64, activation='relu'),                       
    Dense(48, activation='relu'),       
    Dense(34, activation='relu'),
    Dense(24, activation='relu'),
    Dense(16, activation='relu'),
    Dense(10, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])
model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 80)                4880
#
#  dense_16 (Dense)            (None, 64)                5184
#
#  dense_17 (Dense)            (None, 48)                3120
#
#  dense_18 (Dense)            (None, 34)                1666
#
#  dense_19 (Dense)            (None, 24)                840
#
#  dense_20 (Dense)            (None, 16)                400
#
#  dense_21 (Dense)            (None, 10)                170
#
#  dense_22 (Dense)            (None, 4)                 44
#
#  dense_23 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 16309 (63.71 KB)
# Trainable params: 16309 (63.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model4.compile('adam', 'binary_crossentropy', metrics=['accuracy'])
hist4 = model4.fit(X_train, y_train, validation_split=0.2,
                   epochs=200, batch_size=100, verbose=0)
model4.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5825 - accuracy: 0.8810
# [0.5825371742248535, 0.8809523582458496]

# %%
hl4, params4, acc4 = 8, 16309, 0.8333       # 선생님 기준데이터로 나는 정확느 0.9048임

# %% [markdown]
# - 케이스 비교

# %%
rf = pd.DataFrame({
    '은닉층 갯수': [hl1, hl2, hl3, hl4],
    '파라메타 갯수': [params1, params2, params3, params4],
    '정확도 갯수': [acc1, acc2, acc3, acc4]
})
rf
# 파라메타갯수를 늘릴수록 어느순간 정확도의 값은 변하지 않음
# Out:
#    은닉층 갯수  파라메타 갯수  정확도 갯수
# 0       2     5865  0.8095
# 1       4     9925  0.8333
# 2       6    13947  0.8333
# 3       8    16309  0.8333

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc1 = hist1.history['accuracy']
y_acc2 = hist2.history['accuracy']
y_acc3 = hist3.history['accuracy']
y_acc4 = hist4.history['accuracy']
y_vloss1 = hist1.history['val_loss']
y_vloss2 = hist2.history['val_loss']
y_vloss3 = hist3.history['val_loss']
y_vloss4 = hist4.history['val_loss']
xs = np.arange(1, len(y_acc1)+1)

# %%
plt.figure(figsize=(12,6))
plt.plot(xs, y_acc1, label='case 1')
plt.plot(xs, y_acc2, label='case 2')
plt.plot(xs, y_acc3, label='case 3')
plt.plot(xs, y_acc4, label='case 4')
plt.legend(), plt.grid(), plt.xlabel('epoch')
plt.title('Trainset Accuracy')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(xs, y_vloss1, label='case 1')
plt.plot(xs, y_vloss2, label='case 2')
plt.plot(xs, y_vloss3, label='case 3')
plt.plot(xs, y_vloss4, label='case 4')
plt.legend(), plt.grid(), plt.xlabel('epoch')
plt.title('Validset Loss')
plt.show()

# %% [markdown]
# ![](attachment:image.png)
# val_loss가 최소가 되는 시점이 best-Model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Best Model 만들어 저장하고 사용하기
# - Case 1) 은닉층 2개

# %%
model1b = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model1b.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 80)                4880
#
#  dense_25 (Dense)            (None, 12)                972
#
#  dense_26 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 5865 (22.91 KB)
# Trainable params: 5865 (22.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model1b.compile('adam', 'binary_crossentropy', metrics=['accuracy'])

# %%
# best model만 저장하는 함수
from tensorflow.keras.callbacks import ModelCheckpoint
mc1 = ModelCheckpoint('models/sonar_best1.h5', monitor='val_loss', 
                      verbose=1, save_best_only=True)           # 좋은 녀석이 나타나면 저장하고 계속 돌아감

# %%
# epoch가 종료될 때 마다 callback 함수를 실행하도록 설정
hist1 = model1b.fit(X_train, y_train, validation_split=0.2,
                    epochs=100, batch_size=100, verbose=0,
                    callbacks=[mc1])
# Out:
# Epoch 1: val_loss improved from inf to 0.70845, saving model to models\sonar_best1.h5
#
# Epoch 2: val_loss improved from 0.70845 to 0.68117, saving model to models\sonar_best1.h5
#
# Epoch 3: val_loss improved from 0.68117 to 0.65776, saving model to models\sonar_best1.h5
#
# Epoch 4: val_loss improved from 0.65776 to 0.63780, saving model to models\sonar_best1.h5
#
# Epoch 5: val_loss improved from 0.63780 to 0.61848, saving model to models\sonar_best1.h5
#
# Epoch 6: val_loss improved from 0.61848 to 0.60083, saving model to models\sonar_best1.h5
#
# Epoch 7: val_loss improved from 0.60083 to 0.58598, saving model to models\sonar_best1.h5
#
# Epoch 8: val_loss improved from 0.58598 to 0.57211, saving model to models\sonar_best1.h5
#
# Epoch 9: val_loss improved from 0.57211 to 0.55993, saving model to models\sonar_best1.h5
#
# Epoch 10: val_loss improved from 0.55993 to 0.54872, saving model to models\sonar_best1.h5
#
# Epoch 11: val_loss improved from 0.54872 to 0.53869, saving model to models\sonar_best1.h5
#
# Epoch 12: val_loss improved from 0.53869 to 0.53034, saving model to models\sonar_best1.h5
#
# Epoch 13: val_loss improved from 0.53034 to 0.52302, saving model to models\sonar_best1.h5
#
# Epoch 14: val_loss improved from 0.52302 to 0.51575, saving model to models\sonar_best1.h5
#
# Epoch 15: val_loss improved from 0.51575 to 0.50848, saving model to models\sonar_best1.h5
#
# Epoch 16: val_loss improved from 0.50848 to 0.50101, saving model to models\sonar_best1.h5
#
# Epoch 17: val_loss improved from 0.50101 to 0.49262, saving model to models\sonar_best1.h5
#
# Epoch 18: val_loss improved from 0.49262 to 0.48258, saving model to models\sonar_best1.h5
#
# Epoch 19: val_loss improved from 0.48258 to 0.47318, saving model to models\sonar_best1.h5
#
# Epoch 20: val_loss improved from 0.47318 to 0.46407, saving model to models\sonar_best1.h5
#
# Epoch 21: val_loss improved from 0.46407 to 0.45461, saving model to models\sonar_best1.h5
#
# Epoch 22: val_loss improved from 0.45461 to 0.44487, saving model to models\sonar_best1.h5
#
# Epoch 23: val_loss improved from 0.44487 to 0.43608, saving model to models\sonar_best1.h5
#
# Epoch 24: val_loss improved from 0.43608 to 0.42739, saving model to models\sonar_best1.h5
#
# Epoch 25: val_loss improved from 0.42739 to 0.41903, saving model to models\sonar_best1.h5
#
# Epoch 26: val_loss improved from 0.41903 to 0.41182, saving model to models\sonar_best1.h5
#
# Epoch 27: val_loss improved from 0.41182 to 0.40523, saving model to models\sonar_best1.h5
#
# Epoch 28: val_loss improved from 0.40523 to 0.39901, saving model to models\sonar_best1.h5
#
# Epoch 29: val_loss improved from 0.39901 to 0.39352, saving model to models\sonar_best1.h5
#
# Epoch 30: val_loss improved from 0.39352 to 0.38802, saving model to models\sonar_best1.h5
#
# Epoch 31: val_loss improved from 0.38802 to 0.38350, saving model to models\sonar_best1.h5
#
# Epoch 32: val_loss improved from 0.38350 to 0.37916, saving model to models\sonar_best1.h5
#
# Epoch 33: val_loss improved from 0.37916 to 0.37469, saving model to models\sonar_best1.h5
#
# Epoch 34: val_loss improved from 0.37469 to 0.37008, saving model to models\sonar_best1.h5
#
# Epoch 35: val_loss improved from 0.37008 to 0.36595, saving model to models\sonar_best1.h5
#
# Epoch 36: val_loss improved from 0.36595 to 0.36272, saving model to models\sonar_best1.h5
#
# Epoch 37: val_loss improved from 0.36272 to 0.36023, saving model to models\sonar_best1.h5
#
# Epoch 38: val_loss improved from 0.36023 to 0.35853, saving model to models\sonar_best1.h5
#
# Epoch 39: val_loss improved from 0.35853 to 0.35708, saving model to models\sonar_best1.h5
#
# Epoch 40: val_loss improved from 0.35708 to 0.35567, saving model to models\sonar_best1.h5
#
# Epoch 41: val_loss improved from 0.35567 to 0.35472, saving model to models\sonar_best1.h5
#
# Epoch 42: val_loss improved from 0.35472 to 0.35418, saving model to models\sonar_best1.h5
#
# Epoch 43: val_loss improved from 0.35418 to 0.35342, saving model to models\sonar_best1.h5
#
# Epoch 44: val_loss improved from 0.35342 to 0.35126, saving model to models\sonar_best1.h5
#
# Epoch 45: val_loss improved from 0.35126 to 0.34961, saving model to models\sonar_best1.h5
#
# Epoch 46: val_loss improved from 0.34961 to 0.34814, saving model to models\sonar_best1.h5
#
# Epoch 47: val_loss improved from 0.34814 to 0.34616, saving model to models\sonar_best1.h5
#
# Epoch 48: val_loss improved from 0.34616 to 0.34422, saving model to models\sonar_best1.h5
#
# Epoch 49: val_loss improved from 0.34422 to 0.34219, saving model to models\sonar_best1.h5
#
# Epoch 50: val_loss improved from 0.34219 to 0.33945, saving model to models\sonar_best1.h5
#
# Epoch 51: val_loss improved from 0.33945 to 0.33685, saving model to models\sonar_best1.h5
#
# Epoch 52: val_loss improved from 0.33685 to 0.33498, saving model to models\sonar_best1.h5
#
# Epoch 53: val_loss improved from 0.33498 to 0.33283, saving model to models\sonar_best1.h5
#
# Epoch 54: val_loss improved from 0.33283 to 0.33079, saving model to models\sonar_best1.h5
#
# Epoch 55: val_loss improved from 0.33079 to 0.32918, saving model to models\sonar_best1.h5
#
# Epoch 56: val_loss improved from 0.32918 to 0.32787, saving model to models\sonar_best1.h5
#
# Epoch 57: val_loss improved from 0.32787 to 0.32688, saving model to models\sonar_best1.h5
#
# Epoch 58: val_loss improved from 0.32688 to 0.32613, saving model to models\sonar_best1.h5
#
# Epoch 59: val_loss improved from 0.32613 to 0.32523, saving model to models\sonar_best1.h5
#
# Epoch 60: val_loss improved from 0.32523 to 0.32477, saving model to models\sonar_best1.h5
#
# Epoch 61: val_loss did not improve from 0.32477
#
# Epoch 62: val_loss did not improve from 0.32477
#
# Epoch 63: val_loss did not improve from 0.32477
#
# Epoch 64: val_loss did not improve from 0.32477
#
# Epoch 65: val_loss did not improve from 0.32477
#
# Epoch 66: val_loss did not improve from 0.32477
#
# Epoch 67: val_loss did not improve from 0.32477
#
# Epoch 68: val_loss did not improve from 0.32477
#
# Epoch 69: val_loss did not improve from 0.32477
#
# Epoch 70: val_loss did not improve from 0.32477
#
# Epoch 71: val_loss did not improve from 0.32477
#
# Epoch 72: val_loss did not improve from 0.32477
#
# Epoch 73: val_loss did not improve from 0.32477
#
# Epoch 74: val_loss did not improve from 0.32477
#
# Epoch 75: val_loss did not improve from 0.32477
#
# Epoch 76: val_loss did not improve from 0.32477
#
# Epoch 77: val_loss did not improve from 0.32477
#
# Epoch 78: val_loss did not improve from 0.32477
#
# Epoch 79: val_loss did not improve from 0.32477
#
# Epoch 80: val_loss did not improve from 0.32477
#
# Epoch 81: val_loss did not improve from 0.32477
#
# Epoch 82: val_loss did not improve from 0.32477
#
# Epoch 83: val_loss did not improve from 0.32477
#
# Epoch 84: val_loss did not improve from 0.32477
#
# Epoch 85: val_loss did not improve from 0.32477
#
# Epoch 86: val_loss did not improve from 0.32477
#
# Epoch 87: val_loss did not improve from 0.32477
#
# Epoch 88: val_loss did not improve from 0.32477
#
# Epoch 89: val_loss did not improve from 0.32477
#
# Epoch 90: val_loss did not improve from 0.32477
#
# Epoch 91: val_loss did not improve from 0.32477
#
# Epoch 92: val_loss did not improve from 0.32477
#
# Epoch 93: val_loss did not improve from 0.32477
#
# Epoch 94: val_loss did not improve from 0.32477
#
# Epoch 95: val_loss did not improve from 0.32477
#
# Epoch 96: val_loss did not improve from 0.32477
#
# Epoch 97: val_loss did not improve from 0.32477
#
# Epoch 98: val_loss did not improve from 0.32477
#
# Epoch 99: val_loss did not improve from 0.32477
#
# Epoch 100: val_loss did not improve from 0.32477

# %%
# best model 불러와서 평가하기
from tensorflow.keras.models import load_model

best_model1 = load_model('models/sonar_best1.h5')
best_model1.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 17ms/step - loss: 0.4190 - accuracy: 0.8095
# [0.41896796226501465, 0.8095238208770752]

# %%
best_score = [0.8571]           # 0.8571은 선생님 데이터 / 나는 0.8095....

# %% [markdown]
# - Case 2) 은닉층 4개

# %%
model2b = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(48, activation='relu'),
    Dense(20, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %%
model2b.compile('adam', 'binary_crossentropy', metrics=['accuracy'])
mc2 = ModelCheckpoint('models/sonar_best2.h5', monitor='val_loss', 
                      verbose=0, save_best_only=True)
hist2 = model2b.fit(X_train, y_train, validation_split=0.2,
                    epochs=100, batch_size=100, verbose=0,
                    callbacks=[mc2])
best_model2 = load_model('models/sonar_best2.h5')
best_model2.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2798 - accuracy: 0.8810
# [0.2798026502132416, 0.8809523582458496]

# %%
best_score.append(0.9048)           # 정확도 선생님 데이터 : 0.8571 / 나: 0.8810

# %% [markdown]
# - Case 3)은닉층 6개

# %%
model3b = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(64, activation='relu'),
    Dense(40, activation='relu'),
    Dense(24, activation='relu'),
    Dense(10, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %%
model3b.compile('adam', 'binary_crossentropy', metrics=['accuracy'])
mc3 = ModelCheckpoint('models/sonar_best3.h5', monitor='val_loss', 
                      verbose=0, save_best_only=True)
hist3 = model3b.fit(X_train, y_train, validation_split=0.2,
                    epochs=100, batch_size=100, verbose=0,
                    callbacks=[mc3])
best_model3 = load_model('models/sonar_best3.h5')
best_model3.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6138 - accuracy: 0.7381
# [0.6137701869010925, 0.738095223903656]

# %%
best_score.append(0.8095)           # 정확도 선생님 데이터 : 0.5238 / 나: 0.7381

# %% [markdown]
# - Case 4) 은닉층 8개

# %%
model4b = Sequential([
    Dense(80, input_dim=60, activation='relu'),          # 여기부터 은닉층
    Dense(64, activation='relu'),                       
    Dense(48, activation='relu'),       
    Dense(34, activation='relu'),
    Dense(24, activation='relu'),
    Dense(16, activation='relu'),
    Dense(10, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %%
model4b.compile('adam', 'binary_crossentropy', metrics=['accuracy'])
mc4 = ModelCheckpoint('models/sonar_best4.h5', monitor='val_loss', 
                      verbose=0, save_best_only=True)
hist4 = model4b.fit(X_train, y_train, validation_split=0.2,
                    epochs=100, batch_size=100, verbose=0,
                    callbacks=[mc4])
best_model4 = load_model('models/sonar_best4.h5')
best_model4.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5805 - accuracy: 0.8095
# [0.5804905891418457, 0.8095238208770752]

# %%
best_score.append(0.7380)           # 정확도 선생님 데이터 : 0.8571 / 나: 0.8095

# %%
rf['best model'] = best_score
rf
# Out:
#    은닉층 갯수  파라메타 갯수  정확도 갯수  best model
# 0       2     5865  0.8095      0.8571
# 1       4     9925  0.8333      0.8571
# 2       6    13947  0.8333      0.5238
# 3       8    16309  0.8333      0.8571
